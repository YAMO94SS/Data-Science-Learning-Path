# %%
texto = input("Escribe una frase: ")
conteo = {}

# comience su código aquí:
palabras = texto.split()
for palabra in palabras:
   if palabra not in conteo:
      conteo[palabra] = 1
   else:
      conteo[palabra] += 1
print(conteo)
# Out:
# Escribe una frase:  El amor es una locura que ni el cura lo cura porque si el cura lo cura sería una locura del cura
# {'El': 1, 'amor': 1, 'es': 1, 'una': 2, 'locura': 2, 'que': 1, 'ni': 1, 'el': 2, 'cura': 5, 'lo': 2, 'porque': 1, 'si': 1, 'sería': 1, 'del': 1}
